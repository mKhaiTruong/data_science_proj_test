# %%
import os

# %pwd
# Out:
# 'd:\\Deep_Learning_Object_Detection\\MLOPs\\data_science_proj_test\\research'

# %%
os.chdir("../")
# %pwd
# Out:
# 'd:\\Deep_Learning_Object_Detection\\MLOPs\\data_science_proj_test'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.data_science.constants import *
from src.data_science.utils.common import read_yaml, create_directories

class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)
        

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
        )

        return data_transformation_config

# %%
import os, pandas as pd
from src.data_science import logger
from sklearn.model_selection import train_test_split

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config
        
    def train_test_spliting(self):
        data = pd.read_csv(self.config.data_path)
        train, test = train_test_split(data)
        
        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index=False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index=False)
        
        logger.info(f"Splitting data into training and testing sets")
        logger.info(train.shape); logger.info(test.shape)
        
        print(train.shape); print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_spliting()
except Exception as e:
    raise e
# Out:
# [2026-03-22 11:52:10,538: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-03-22 11:52:10,554: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-03-22 11:52:10,564: INFO: common: yaml file: schema.yaml loaded successfully]
# [2026-03-22 11:52:10,565: INFO: common: created directory at: artifacts]
# [2026-03-22 11:52:10,577: INFO: common: created directory at: artifacts/data_transformation]
# [2026-03-22 11:52:10,616: INFO: 3822413733: Splitting data into training and testing sets]
# [2026-03-22 11:52:10,618: INFO: 3822413733: (1199, 12)]
# [2026-03-22 11:52:10,619: INFO: 3822413733: (400, 12)]
# (1199, 12)
# (400, 12)
